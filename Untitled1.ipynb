# %%
import requests as r
import shutil
import os
import string
import time
from bs4 import BeautifulSoup
index =r.get("http://www.timliao.com/bbs/forumMain.php?fid=18&filter=604800&orderby=dateline&ascdesc=DESC")
index1 =r.get("http://www.timliao.com/bbs/forumMain.php?fid=18&filter=604800&orderby=views&ascdesc=DESC")
index.encoding='big5'
index1.encoding='big5'
soup=BeautifulSoup(index.text,"html5lib")
soup1=BeautifulSoup(index1.text,"html5lib")
soup.append(soup1)
til=soup.select('td.all > a')
resource=soup.select("td.all > a")
resource=[res["href"] for res in resource ]
title=[]
for i in range(0,len(til)):
    title.append(til[i].text.replace('\n',' ')
                       .replace('\u3000',' ')
                       .split("[")[0]
                       .split()[1])
j=0
for res in resource:
    i=0
    #!mkdir "%s"%res
    #!cd "%s"%res
    path="/home/ubuntu/Documents/timliao/%s"%title[j]
    if  os.path.isdir(path):
        continue
    else:
        os.mkdir(path)
    req=r.get(res)
    soup=BeautifulSoup(req.text,"html5lib")
    pics=soup.select("a > img.imglimit")
    pics=[pic["src"] for pic in pics]
    for url1 in pics:
        try:
            print(url1)
            #if os.path.exists(url1):
            res = r.get(url1, stream=True)
            with open(path+"/"+'%s.jpg'%i, 'wb') as f:
                shutil.copyfileobj(res.raw, f)
                i+=1
                time.sleep(1)
        except:
            print("error")
    j+=1
# Out:
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-9/17457404_10212749249992939_8215123252852423893_n.jpg?oh=419a90e2e80c060f18601c8382f62420&oe=5A4E67E7
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-9/20245859_10214039005076010_1379570776755623684_n.jpg?oh=4460db9a041ddde48e6168f7e18be3d3&oe=5A43C035
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-9/21616327_10214596413250866_7197901811832486673_n.jpg?oh=1e9949683a809adc166c4913f62d7230&oe=5A3B7AE1
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-9/16602981_10212277013907332_2899859403431435763_n.jpg?oh=d638f89f22f7d7449f35e0ddb53021f2&oe=5A85A61D
# https://scontent-tpe1-1.xx.fbcdn.net/v/t1.0-9/15965215_10212060117765064_177204025437313643_n.jpg?oh=fd8aea61e075aa1388c87b86c3be0eed&oe=5A4BD971
# https://scontent-tpe1-1.cdninstagram.com/t51.2885-15/e35/21568564_1487060604712756_5006730642092720128_n.jpg
# https://scontent-tpe1-1.cdninstagram.com/t51.2885-15/e35/21980539_118151058865865_230326400161153024_n.jpg
# ...

# %%
import requests as r
from bs4 import BeautifulSoup
import os
import shutil
import urllib
import re
import random


def get_proxy(): 
    url="http://www.xicidaili.com" 
    head={}
    proxies=[]
    head['Agent']='Mozilla/5.0 (Linux; Android 4.0.4; Galaxy Nexus Build/IMM76B) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.133 Mobile Safari/535.19'
    req=urllib.request.Request(url,headers=head) 
    response=urllib.request.urlopen(req) 
    html=response.read().decode("utf-8") 
    IP = re.compile('(\d+)\.(\d+)\.(\d+)\.(\d+)\s*(\d+)') 
    proxy_ip=IP.findall(html) 
    for each in proxy_ip: 
        proxies.append(":".join([(".".join(each[0:4])),each[4]])) 
    return proxies 

res=r.get("http://www.timliao.com/bbs/forumdisplay.php?fid=18&page=1")
res.encoding='big5'
soup=BeautifulSoup(res.text,'html5lib')
url=[]
i=1
last_page=soup.find('a',attrs={'title':'Last Page'})
last_page_url='http://www.timliao.com/bbs/'+last_page['href']
last_page_url
while True:
    res=r.get("http://www.timliao.com/bbs/forumdisplay.php?fid=18&page=%s"%i)
    res.encoding='big5'
    soup=BeautifulSoup(res.text,'html5lib')
    for a in soup.select('h2.subject > a'):
        try:
            if not a['href']=='http://www.timliao.com':
                if a['href']:
                    url.append('http://www.timliao.com/bbs/'+a['href'])
                    print(a['href'])
        except:
            pass
    if ("http://www.timliao.com/bbs/forumdisplay.php?fid=18&page=%s"%i==last_page_url):
        break
    i+=1
    
proxy=[]
for u in url:
    proxy_ip={}
    proxy = get_proxy()
    proxy_ip['http']=proxy[random.randint(0,len(proxy)-1)]
    proxy_support = request.ProxyHandler()
    opener = request.build_opener(proxy_support)
    opener.addheaders = [('User-Agent','Mozilla/5.0 (Linux; Android 4.0.4; Galaxy Nexus Build/IMM76B) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.133 Mobile Safari/535.19')]
    request.install_opener(opener)
    response = request.urlopen(u)
    res = response.read().decode("big5")
    soup=BeautifulSoup(res,'html5lib')
    title=soup.select('h1.head')
    title=title[0].text.replace('\u3000',' ')
    pics= [i['src']for i in soup.select('img.imglimit')]
    pics
    path='/media/ubuntu/WVIIAM/timliao/'+title
    if not os.path.isdir(path):
        os.mkdir(path)
    else :
        continue
    j=1
    for pic in pics:
        res=r.get(pic,stream=True)
        with open(path+'/%s.jpg'%j,'wb') as f:
            shutil.copyfileobj(res.raw,f)
        j+=1

# %%
len(url)

# %%
p=0
for u in url:
    try:
        proxy = [{'http':'64.40.229.51:80'},{'http':'35.187.81.58:80'},{'http':'47.89.177.117:80'}]
        proxy_support = request.ProxyHandler(proxy[p])
        opener = request.build_opener(proxy_support)
        opener.addheaders = [('User-Agent','Mozilla/5.0 (Linux; Android 4.0.4; Galaxy Nexus Build/IMM76B) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.133 Mobile Safari/535.19')]
        request.install_opener(opener)
        response = request.urlopen(u)
        res = response.read().decode("big5")
        soup=BeautifulSoup(res,'html5lib')
        title=soup.select('h1.head')
        title=title[0].text.replace('\u3000',' ')
        pics= [i['src']for i in soup.select('img.imglimit')]
        pics
        path='/media/ubuntu/WVIIAM/timliao/'+title
        if not os.path.isdir(path):
            os.mkdir(path)
        else :
            continue
        j=1
        for pic in pics:
            res=r.get(pic,stream=True)
            with open(path+'/%s.jpg'%j,'wb') as f:
                shutil.copyfileobj(res.raw,f)
            j+=1
        print(u)
    except:
        p=(p+1)%3
        proxy_support = request.ProxyHandler(proxy[p])
        opener = request.build_opener(proxy_support)
        opener.addheaders = [('User-Agent','Mozilla/5.0 (Linux; Android 4.0.4; Galaxy Nexus Build/IMM76B) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.133 Mobile Safari/535.19')]
        request.install_opener(opener)
        response = request.urlopen(u)
        res = response.read().decode("big5")
        soup=BeautifulSoup(res,'html5lib')
        title=soup.select('h1.head')
        title=title[0].text.replace('\u3000',' ')
        pics= [i['src']for i in soup.select('img.imglimit')]
        pics
        path='/media/ubuntu/WVIIAM/timliao/'+title
        if not os.path.isdir(path):
            os.mkdir(path)
        else :
            continue
        j=1
        for pic in pics:
            res=r.get(pic,stream=True)
            with open(path+'/%s.jpg'%j,'wb') as f:
                shutil.copyfileobj(res.raw,f)
            j+=1
        print(u)

# %%
import requests as r
from bs4 import BeautifulSoup
import os
import shutil
import urllib
import re
import random
from time import sleep

res=r.get("http://www.timliao.com/bbs/forumdisplay.php?fid=18&page=1")
res.encoding='big5'
soup=BeautifulSoup(res.text,'html5lib')
url=[]
i=1
last_page=soup.find('a',attrs={'title':'Last Page'})
last_page_url='http://www.timliao.com/bbs/'+last_page['href']
last_page_url
while True:
    res=r.get("http://www.timliao.com/bbs/forumdisplay.php?fid=18&page=%s"%i)
    res.encoding='big5'
    soup=BeautifulSoup(res.text,'html5lib')
    for a in soup.select('h2.subject > a'):
        try:
            if not a['href']=='http://www.timliao.com':
                if a['href']:
                    url.append('http://www.timliao.com/bbs/'+a['href'])
                    print(a['href'])
        except:
            pass
    if ("http://www.timliao.com/bbs/forumdisplay.php?fid=18&page=%s"%i==last_page_url):
        break
    i+=1

# %%
import requests as r
from bs4 import BeautifulSoup
import os
import shutil
import urllib
import re
import random
from time import sleep

def get_proxy():
    url_proxy="http://www.xicidaili.com" 
    headers={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.101 Safari/537.36'}
    res=r.get(url_proxy,headers=headers)
    soup=BeautifulSoup(res.text,'html5lib')
    soup=soup.select_one('tr.odd')
    html=soup.select('td')[1].text
    port=soup.select('td')[2].text
    port
    proxy=html+':'+port
    return proxy
        
    
for u in url:
    for reconnect in range(1,100):
        try:
            #proxy_ip={}
            #proxy = get_proxy()
            #proxy_ip['http']=proxy
            #proxy_support = urllib.request.ProxyHandler(proxy_ip)
            #opener = urllib.request.build_opener(proxy_support)
            #opener.addheaders = [('User-Agent','Mozilla/5.0 (Linux; Android 4.0.4; Galaxy Nexus Build/IMM76B) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.133 Mobile Safari/535.19')]
            #urllib.request.install_opener(opener)
            #response = urllib.request.urlopen(u)
            #res = response.read().decode("big5")
            
            res=r.get(u)
            res.encoding='big5'
            soup=BeautifulSoup(res.text,'html5lib')
            title=soup.select('h1.head')
            title=title[0].text.replace('\u3000',' ')
            pics= [i['src']for i in soup.select('img.imglimit')]
            pics
            path='/media/ubuntu/WVIIAM/timliao/'+title
            if not os.path.isdir(path):
                os.mkdir(path)
            else :
                continue
            j=1
            for pic in pics:
                if '&amp' in pic:
                    pic=pic.replace('&amp','')
                res=r.get(pic,stream=True)
                with open(path+'/%s.jpg'%j,'wb') as f:
                    shutil.copyfileobj(res.raw,f)
                j+=1
                sleep(0.5)
            sleep(60)
            break
        except Exception as e:
            if reconnect==99:
                print(reconnect)
                print(e)
            sleep(5)
            continue

# %%
from time import sleep
repeat=5
for u in url:
    for i in range(repeat): 
        try:
            res=r.get(u)
            res.encoding='big5'
            break
        except:
            if i<repeat-1:
                continue
            else:
                print('all time is error')
    soup=BeautifulSoup(res.text,'html5lib')        
    title=soup.select('h1.head')
    title=title[0].text.replace('\u3000',' ')
    pics= [i['src']for i in soup.select('img.imglimit')]
    pics
    path='/media/ubuntu/WVIIAM/timliao/'+title
    if not os.path.isdir(path):
        os.mkdir(path)
    else :
        continue
    j=1
    for pic in pics:
        res=r.get(pic,stream=True)
        with open(path+'/%s.jpg'%j,'wb') as f:
            shutil.copyfileobj(res.raw,f)
        j+=1
    sleep(5)

# %%
import urllib
import re
def get_proxy(): 
    url="http://www.xicidaili.com" 
    head={}
    proxies=[]
    head['Agent']='Mozilla/5.0 (Linux; Android 4.0.4; Galaxy Nexus Build/IMM76B) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.133 Mobile Safari/535.19'
    req=urllib.request.Request(url,headers=head) 
    response=urllib.request.urlopen(req) 
    html=response.read().decode("utf-8") 
    IP = re.compile('(\d+)\.(\d+)\.(\d+)\.(\d+)\s*(\d+)') 
    proxy_ip=IP.findall(html)
    i=0
    for each in proxy_ip: 
        proxies.append(":".join([(".".join(each[0:4])),each[4]]))
    return proxies

# %%
get_proxy()

# %%
proxy=[]
for u in url:
    proxy_ip={}
    proxy = get_proxy()
    proxy_ip['http']=proxy[random.randint(0,len(proxy)-1)]
    proxy_support = request.ProxyHandler()
    opener = request.build_opener(proxy_support)
    opener.addheaders = [('User-Agent','Mozilla/5.0 (Linux; Android 4.0.4; Galaxy Nexus Build/IMM76B) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.133 Mobile Safari/535.19')]
    request.install_opener(opener)
    response = request.urlopen(u)
    res = response.read().decode("big5")
    soup=BeautifulSoup(res,'html5lib')
    title=soup.select('h1.head')
    title=title[0].text.replace('\u3000',' ')
    pics= [i['src']for i in soup.select('img.imglimit')]
    pics
    path='/media/ubuntu/WVIIAM/timliao/'+title
    if not os.path.isdir(path):
        os.mkdir(path)
    else :
        continue
    j=1
    for pic in pics:
        res=r.get(pic,stream=True)
        with open(path+'/%s.jpg'%j,'wb') as f:
            shutil.copyfileobj(res.raw,f)
        j+=1

# %%
get_proxy()

# %%
import requests as r
from bs4 import BeautifulSoup
import os
import shutil
import urllib
import re
import random
from time import sleep

def get_proxy():
    url="http://www.xicidaili.com" 
    headers={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.101 Safari/537.36'}
    res=r.get(url,headers=headers)
    soup=BeautifulSoup(res.text,'html5lib')
    soup=soup.select_one('tr.odd')
    html=soup.select('td')[1].text
    port=soup.select('td')[2].text
    port
    proxy=html+':'+port
    return proxy

# %%
get_proxy()
